# %% [markdown]
# # TMDB Datenbeschaffung
# In diesem Notebook werden Filmdaten von TMDB beschaffen. Dafür müssen wir uns mit der TMDB API verbinden. Es gibt eine Python Bibliothek "tmdbsimple", die dies ermöglicht.
#
# Quelle: https://github.com/celiao/tmdbsimple
#
# Diese Filmdaten enthalten zum Beispiel den Titel, die Genres, die Filmbeschreibung, die Filmdauer, Produktionsländer und viele andere Attribute. Danach werden die Daten als Dataframe gespeichert und als csv exportiert, um später zu reinigen.
#
# Diese Daten werden schlussendlich mit den movielens Daten verbunden --> so können wir später auf die jeweiligen Ratings von den abefragten Filmen zugreifen.

# %%
import tmdbsimple as tmdb
import requests
import pandas as pd
from datetime import datetime

# %%
# read movie IDs (movieId & tmdbId)
df_movie_ids = pd.read_csv('ml-25m/links.csv', usecols = ["movieId", "tmdbId"])
df_movie_ids.head()
# Out:
#    movieId   tmdbId
# 0        1    862.0
# 1        2   8844.0
# 2        3  15602.0
# 3        4  31357.0
# 4        5  11862.0

# %%
# print number of missing values
print(df_movie_ids.isna().sum())
# Out:
# movieId      0
# tmdbId     107
# dtype: int64

# %%
# Remove 107 missing values from column tmdbId
df_movie_ids = df_movie_ids[df_movie_ids["tmdbId"].notna()]

print(df_movie_ids.isna().sum())
# Out:
# movieId    0
# tmdbId     0
# dtype: int64

# %% [markdown]
# Hier werden die Filmdaten von der TMDB API abgefragt und, solange der Film später wie 2000 veröffentlicht wurde, in einem Dataframe abgespeichert und exportieren.

# %%
tmdb.API_KEY = "f831ad4674ee3f8502035db2a48af4c6"
movie_lst = []

# loop through all tmdb IDs
for movie_id in df_movie_ids["tmdbId"]:
    
    try:
        # set timeout
        tmdb.REQUESTS_TIMEOUT = (2, 5)

        # create session
        tmdb.REQUESTS_SESSION = requests.Session()
        
        # request movie data with movie_id
        movie = tmdb.Movies(movie_id)
        
        # get movie information (dict)
        response = movie.info()
                
        # check if release date is after 2010, add to movie list if its true
        if datetime.strptime(movie.release_date, "%Y-%m-%d") >= datetime.strptime("2010-01-01", "%Y-%m-%d"):
            movie_lst.append(response)
        
    except Exception as e:
        
        print(e)
    
df_movies = pd.DataFrame(movie_lst)
# Out:
#        adult                     backdrop_path belongs_to_collection   budget  \
# 0      False  /s2bpgVhpWODDfoADW78IpMDCMTR.jpg                  None  1783810
# 1      False                              None                  None        0
# 2      False                              None                  None        0
# 3      False                              None                  None        0
# 4      False                              None                  None        0
# ...      ...                               ...                   ...      ...
# 19958  False  /n7kr24jkZBg6EERpJBdKvOjMMdV.jpg                  None        0
# 19959  False  /4evYVAzIHXSSVFxCQhBgkgj52pH.jpg                  None        0
# 19960  False  /ekVWMz32hsrRuSLf5KTjg3PvcUa.jpg                  None        0
# 19961  False  /3kb5b8IQCX4vd3baNBoZqAboP41.jpg                  None        0
# 19962  False  /aIOcHbrugaUSODshOOcjhgNYj8a.jpg                  None        0
#
#                                                   genres  \
# 0      [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1      [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 2                          [{'id': 18, 'name': 'Drama'}]
# 3                    [{'id': 99, 'name': 'Documentary'}]
# 4      [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# ...                                                  ...
# 19958  [{'id': 99, 'name': 'Documentary'}, {'id': 36,...
# 19959  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 19960                    [{'id': 36, 'name': 'History'}]
# 19961                      [{'id': 18, 'name': 'Drama'}]
# 19962  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                    homepage      id     imdb_id  \
# 0                                             79782   tt1684935
# 1                                            141210   tt2250194
# 2      http://www.thefarmerswifefilm.co.uk/  143750   tt2140519
# 3                                             84198   tt1736049
# 4                                            171982   tt2378428
# ...                                     ...     ...         ...
# 19958                                        646282   tt8132166
# 19959                                        595924  tt10199670
# 19960                                        622831  tt10551150
# 19961                                        499546   tt6671244
# 19962                                        553036   tt6755366
#
#       original_language        original_title  ... release_date   revenue  \
# 0                    pl               Wenecja  ...   2010-06-11         0
# 1                    en         The Sleepover  ...   2012-10-12         0
# 2                    en     The Farmer's Wife  ...   2012-06-20         0
# 3                    en  A Place at the Table  ...   2012-03-22         0
# 4                    en               Romance  ...   2012-10-09         0
# ...                 ...                   ...  ...          ...       ...
# 19958                es             El cuadro  ...   2019-11-08         0
# 19959                fr               Liberté  ...   2019-09-04         0
# 19960                zh                  決勝時刻  ...   2019-09-20  15030400
# 19961                nl                   Wij  ...   2018-07-12         0
# 19962                hu          Rossz versek  ...   2018-12-27         0
#
#       runtime                                   spoken_languages    status  \
# 0         110  [{'english_name': 'Czech', 'iso_639_1': 'cs', ...  Released
# 1           6  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2          18  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3          84  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4          27  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# ...       ...                                                ...       ...
# 19958     107  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 19959     132  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
# 19960       0  [{'english_name': 'Mandarin', 'iso_639_1': 'zh...  Released
# 19961     100  [{'english_name': 'Dutch', 'iso_639_1': 'nl', ...  Released
# 19962      97  [{'english_name': 'French', 'iso_639_1': 'fr',...  Released
#
#                                tagline                 title  video  \
# 0                                                     Venice  False
# 1                                              The Sleepover  False
# 2                                          The Farmer's Wife  False
# 3                One Nation. Underfed.  A Place at the Table  False
# 4                                                    Romance  False
# ...                                ...                   ...    ...
# 19958  What is happening in that room?          The Painting  False
# 19959                                                Liberte  False
# 19960                                        Mao Zedong 1949  False
# 19961                                                     We  False
# 19962                                              Bad Poems  False
#
#       vote_average vote_count
# 0            7.000         13
# 1            6.600          8
# 2           10.000          1
# 3            6.700         20
# 4            6.000          1
# ...            ...        ...
# 19958        8.000          2
# 19959        5.400         22
# 19960        5.700          6
# 19961        5.938         56
# 19962        6.900         11
#
# [19963 rows x 25 columns]

# %% [markdown]
# Filme ab 2010 als csv abspeichern

# %%
# save dataframe to csv
df_movies.to_csv("tmdb_movies.csv", sep="\t")
